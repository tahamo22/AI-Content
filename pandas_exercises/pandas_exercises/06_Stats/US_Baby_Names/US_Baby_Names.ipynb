# %% [markdown]
# # US - Baby Names

# %% [markdown]
# ### Introduction:
#
# We are going to use a subset of [US Baby Names](https://www.kaggle.com/kaggle/us-baby-names) from Kaggle.
# In the file it will be names from 2004 until 2014
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called baby_names.

# %%
baby_names = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv')

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
baby_names.head(10)
# Out:
#    Unnamed: 0     Id      Name  Year Gender State  Count
# 0       11349  11350      Emma  2004      F    AK     62
# 1       11350  11351   Madison  2004      F    AK     48
# 2       11351  11352    Hannah  2004      F    AK     46
# 3       11352  11353     Grace  2004      F    AK     44
# 4       11353  11354     Emily  2004      F    AK     41
# 5       11354  11355   Abigail  2004      F    AK     37
# 6       11355  11356    Olivia  2004      F    AK     33
# 7       11356  11357  Isabella  2004      F    AK     30
# 8       11357  11358    Alyssa  2004      F    AK     29
# 9       11358  11359    Sophia  2004      F    AK     28

# %% [markdown]
# ### Step 5. Delete the column 'Unnamed: 0' and 'Id'

# %%
baby_names.drop(['Unnamed: 0', 'Id'], axis=1, inplace=True)

# %%
baby_names
# Out:
#             Name  Year Gender State  Count
# 0           Emma  2004      F    AK     62
# 1        Madison  2004      F    AK     48
# 2         Hannah  2004      F    AK     46
# 3          Grace  2004      F    AK     44
# 4          Emily  2004      F    AK     41
# ...          ...   ...    ...   ...    ...
# 1016390     Seth  2014      M    WY      5
# 1016391  Spencer  2014      M    WY      5
# 1016392     Tyce  2014      M    WY      5
# 1016393   Victor  2014      M    WY      5
# 1016394   Waylon  2014      M    WY      5
#
# [1016395 rows x 5 columns]

# %% [markdown]
# ### Step 6. Is there more male or female names in the dataset?

# %%
male = baby_names[baby_names['Gender'] == 'M']
female = baby_names[baby_names['Gender'] == 'F']
print("the num of males is :",len(male))
print("the num of females is :",len(female))
if len(male) > len(female):
    print('More male names in the dataset')
else:
    print('More female names in the dataset')
# Out:
# the num of males is : 457549
# the num of females is : 558846
# More female names in the dataset

# %% [markdown]
# ### Step 7. Group the dataset by name and assign to names

# %%
baby_names.groupby('Name')

# %% [markdown]
# ### Step 8. How many different names exist in the dataset?

# %%
names = baby_names.groupby('Name')
len(names)
# Out:
# 17632

# %% [markdown]
# ### Step 9. What is the name with most occurrences?

# %%
names.sum().sort_values('Count', ascending=False).head(1)
# Out:
#           Year                                             Gender  \
# Name
# Jacob  1141099  MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMM...
#
#                                                    State   Count
# Name
# Jacob  AKAKAKAKAKAKAKAKAKAKAKALALALALALALALALALALALAR...  242874

# %% [markdown]
# ### Step 10. How many different names have the least occurrences?

# %%
names.sum().sort_values('Count', ascending=True).head(1)
# Out:
#        Year Gender State  Count
# Name
# Shabd  2007      M    CA      5

# %% [markdown]
# ### Step 11. What is the median name occurrence?

# %%
median_name = baby_names.groupby('Name').median(numeric_only=True)
median_name
# Out:
#            Year  Count
# Name
# Aaban    2013.5    6.0
# Aadan    2008.5    5.5
# Aadarsh  2009.0    5.0
# Aaden    2010.0   10.0
# Aadhav   2014.0    6.0
# ...         ...    ...
# Zyra     2013.0    6.0
# Zyrah    2012.0    5.5
# Zyren    2013.0    6.0
# Zyria    2008.0    6.0
# Zyriah   2009.0    6.0
#
# [17632 rows x 2 columns]

# %% [markdown]
# ### Step 12. What is the standard deviation of names?

# %%
std_name = baby_names.groupby('Name').std(numeric_only=True)
std_name
# Out:
#              Year      Count
# Name
# Aaban    0.707107   0.000000
# Aadan    2.872281   0.957427
# Aadarsh       NaN        NaN
# Aaden    2.044322  21.154974
# Aadhav        NaN        NaN
# ...           ...        ...
# Zyra     2.115701   1.154701
# Zyrah    1.414214   0.707107
# Zyren         NaN        NaN
# Zyria    2.685351   0.737865
# Zyriah   2.915476   1.666667
#
# [17632 rows x 2 columns]

# %% [markdown]
# ### Step 13. Get a summary with the mean, min, max, std and quartiles.

# %%
baby_names.describe()
# Out:
#                Year         Count
# count  1.016395e+06  1.016395e+06
# mean   2.009053e+03  3.485012e+01
# std    3.138293e+00  9.739735e+01
# min    2.004000e+03  5.000000e+00
# 25%    2.006000e+03  7.000000e+00
# 50%    2.009000e+03  1.100000e+01
# 75%    2.012000e+03  2.600000e+01
# max    2.014000e+03  4.167000e+03
